# %% [markdown]
# 1. Basic

# %%
age = 19
if age>=18:
    print("You are eligible for driving")
# Out:
# You are eligible for driving

# %%
age = 19
if age<17:
    print("Helloooooooooooo")

# %%
age = 19
if age >20:
    print("Ram")
else:
    print("Ajay")
# Out:
# Ajay

# %% [markdown]
# 2. To check Positive and Negative no

# %%
num = int(input("Enter no : "))
if num >=0:
    print("Num is Positive")
else:
    print("Num is negative")
# Out:
# Num is Positive

# %% [markdown]
# 3. Find the largest of two numbers.

# %%
num1 = int(input())
num2 = int(input())
if num1>=num2:
    print("num1 is a largest no")
elif num2>=num1:
    print("num2 is a largest no")
else:
    print ("no largest no")

# %%
num = 45
if num/2:
    print("The no is even no ")
else:
    print("The no is odd no ")
# Out:
# The no is even no

# %% [markdown]
# 4. Find the Grade

# %%
marks = 85
if marks >= 90:
    print("A")
elif marks >= 80:
    print("B")
elif marks >= 70:
    print("C")
else:
    print("F")
# Out:
# B

# %% [markdown]
# 5. Find the temperature

# %%
temp = 35
if temp >= 40:
    print("Very Hot")
elif temp >= 30:
    print("Hot")
elif temp >= 20:
    print("Warm")
else:
    print("Cold")
# Out:
# Hot
